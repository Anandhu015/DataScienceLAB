# %%
import csv
import matplotlib.pyplot as plt
file = open("medal.csv")
csvreader =list(csv.reader(file))
rows=csvreader[1:]
x1=[]
x2=[]
for each in rows:
    x1.append(each[1])
    x2.append(each[0])   
plt.pie(x1,labels=x2)
file.close()
